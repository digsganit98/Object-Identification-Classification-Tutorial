# %% [markdown]
# # 05 - Classification Dataset Prep
# Build a labeled index from folder names and create stratified train/val/test splits.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.append(str(PROJECT_ROOT / "src"))

DETECTION_ROOT = PROJECT_ROOT / "rooftop-solar-panels-object-detection"
CLASSIFICATION_ROOT = PROJECT_ROOT / "rooftop-solar-panels-image-classification" / "Faulty_solar_panel"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DETECTION_ROOT exists:", DETECTION_ROOT.exists())
print("CLASSIFICATION_ROOT exists:", CLASSIFICATION_ROOT.exists())
# Out:
# PROJECT_ROOT: C:\Users\DigvijayYadav\Downloads\rooftop-solar-panel-dataset
# DETECTION_ROOT exists: True
# CLASSIFICATION_ROOT exists: True

# %%
from data_utils import build_classification_index, add_stratified_splits

cls_df = build_classification_index(CLASSIFICATION_ROOT)
print("Total classification images:", len(cls_df))
print(cls_df["label"].value_counts())

cls_df = add_stratified_splits(cls_df, seed=42, train_ratio=0.7, val_ratio=0.15)
print(cls_df["split"].value_counts())

out_csv = PROJECT_ROOT / "data/processed/classification_index.csv"
cls_df.to_csv(out_csv, index=False)
print("Saved:", out_csv)
# Out:
# Total classification images: 885
# label
# Bird-drop            207
# Clean                193
# Dusty                190
# Snow-Covered         123
# Electrical-damage    103
# Physical-Damage       69
# Name: count, dtype: int64
# split
# train    619
# val      133
# test     133
# Name: count, dtype: int64
# Saved: C:\Users\DigvijayYadav\Downloads\rooftop-solar-panel-dataset\data\processed\classification_index.csv
